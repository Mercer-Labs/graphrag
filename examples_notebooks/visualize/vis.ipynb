# %%
INPUT_PATH = "/Users/subu/workspace/graphrag/tests/fixtures/min-csv/input"

from graphrag.index.workflows.load_input_documents import load_input_documents
from graphrag.config.models.input_config import InputConfig
from graphrag.config.enums import InputFileType
from graphrag.config.models.storage_config import StorageConfig
from graphrag.storage.factory import StorageFactory
from graphrag.config.enums import StorageType

kwargs = {"type": "file", "base_dir": INPUT_PATH}
storage = StorageFactory.create_storage(StorageType.file.value, kwargs)

docs = await load_input_documents(InputConfig(
    file_type=InputFileType.csv,
    file_pattern=".*\\.csv$",
), storage=storage)
docs
# Out:
#                                                  text  \
# 0   ## Chapter 1\n\nThe thrumming of monitors cast...
# 1   ## Chapter 2\n\nSam Rivera sat alone in a cram...
# 2   ## Chapter 3\n\nThe thrumming of monitors cast...
# 3   \n## Chapter 4\n\nThe corridors of the Dulce m...
# 4   ## Chapter 5\n\nDr. Jordan Hayes clutched the ...
# 5   ## Chapter 6\n\n\*\n\nThe cool darkness of the...
# 6   ## Chapter 7\n\nIn the enclosed space of Dulce...
# 7   ## Chapter 8\n\nThe grit of an earthbound dust...
# 8   ## Chapter 9\n\nThe sterile silence of Dulce B...
# 9   ## Chapter 10\n\nThe corridors of the Dulce mi...
# 10  ## Chapter 11\n\nThe sterile silence of Dulce ...
# 11  ## Chapter 12\n\nThe underground facility of D...
# 12  ## Chapter 13\n\nDr. Jordan Hayes shuffled a s...
# 13  \n## Chapter 14\n\nThe command center of Dulce...
# 14  \n## Chapter 15\n\nIn the clandestine hush of ...
#
#                                                    id      title  \
# 0   0150ad765e0cc2e72631e3ff27ab5d3fdb4f80ea27db60...  dulce.csv
# 1   f60d5e7f6c8684dcd12944a009b98e3cf04f023b2ba110...  dulce.csv
# 2   bbeb6adca0a3b993a0610bc736554c76454fd00d9adff4...  dulce.csv
# 3   8eb5df95e528a8c34b3326b6ef8b8860cfb4b8d65da94c...  dulce.csv
# 4   56102659054609e6adf332d0bbcbba0e41d43a06192b5f...  dulce.csv
# 5   a5562e1a1b6b6d05d871d24d97a52ba2b4fc7b7419109c...  dulce.csv
# 6   f3e5b24ac7ea20e8475a04fc144eb2dbd2f4f52145c31d...  dulce.csv
# 7   61a4fd58afa8a6c7d29ce2ee62cb6e2d7378396017ec58...  dulce.csv
# 8   1447c46a39bafcfccb1d8755b6d042ef7946423f5c373d...  dulce.csv
# 9   7c78e4e190fbb2cc7298ae1251ee536da009be8699eef2...  dulce.csv
# 10  eda9ec67a4abf9b1d2e0f0f7a3db117e0b537e7217af88...  dulce.csv
# 11  721a464645ce818efa1d5b69b7d3233bae42cacebf5493...  dulce.csv
# 12  452215b95aadb088443cd539a4bd8923fdd1666f4177d0...  dulce.csv
# 13  16e3f210e27160c852f7d5185cc812069cbef5c0bc4050...  dulce.csv
# 14  e86278c6951f4ff9fd9c86b7deb0936dd879cf458cb885...  dulce.csv
#
#                 creation_date
# 0   2025-10-29 16:27:21 -0700
# 1   2025-10-29 16:27:21 -0700
# 2   2025-10-29 16:27:21 -0700
# 3   2025-10-29 16:27:21 -0700
# 4   2025-10-29 16:27:21 -0700
# 5   2025-10-29 16:27:21 -0700
# 6   2025-10-29 16:27:21 -0700
# 7   2025-10-29 16:27:21 -0700
# 8   2025-10-29 16:27:21 -0700
# 9   2025-10-29 16:27:21 -0700
# 10  2025-10-29 16:27:21 -0700
# 11  2025-10-29 16:27:21 -0700
# 12  2025-10-29 16:27:21 -0700
# 13  2025-10-29 16:27:21 -0700
# 14  2025-10-29 16:27:21 -0700

# %%
import pandas as pd

data1 = {'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Charlie'], 'City': [1, 2, 3]}
df1 = pd.DataFrame(data1)

data2 = {'ID': [1, 3, 4], 'City': ['New York', 'London', 'Paris']}
df2 = pd.DataFrame(data2)

# Inner join on the 'ID' column
merged_df = df1.merge(df2, on='ID', how='inner', suffixes=('_left', '_right'))
print(merged_df)
# Out:
#    ID     Name  City_left City_right
# 0   1    Alice          1   New York
# 1   3  Charlie          3     London

# %%
from graphrag.prompts.index.extract_graph import GRAPH_EXTRACTION_PROMPT

print(GRAPH_EXTRACTION_PROMPT.format(
    document_type="NEWS", input_text="""
    The Verdantis's Central Institution is scheduled to meet on Monday and Thursday, with the institution planning to release its latest 
    policy decision on Thursday at 1:30 p.m. PDT, followed by a press conference where Central Institution Chair Martin Smith will take 
    questions. Investors expect the Market Strategy Committee to hold its benchmark interest rate steady in a range of 3.5%-3.75%."
    """))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 3
#       1 from graphrag.prompts.index.extract_graph import GRAPH_EXTRACTION_PROMPT
# ----> 3 print(GRAPH_EXTRACTION_PROMPT.format(
#       4     document_type="NEWS", input_text="""
#       5     The Verdantis's Central Institution is scheduled to meet on Monday and Thursday, with the institution planning to release its latest
#       6     policy decision on Thursday at 1:30 p.m. PDT, followed by a press conference where Central Institution Chair Martin Smith will take
#       7     questions. Investors expect the Market Strategy Committee to hold its benchmark interest rate steady in a range of 3.5%-3.75%."
#       8     """))
#
# KeyError: 'tuple_delimiter'
